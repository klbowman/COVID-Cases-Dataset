# %%
import pandas as pd
import chardet

# %%
#Import COVID CSV
with open("Resources/covid.csv", 'rb') as rawdata:
    result = chardet.detect(rawdata.read(10000))

# check what the character encoding might be
print(result)

data = pd.read_csv("Resources/covid.csv", encoding='UTF-8-SIG')
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %%
data.head()
# Out:
#         date      geoid     county       state  cases  cases_avg  \
# 0  1/21/2020  USA-53061  Snohomish  Washington      1       0.14
# 1  1/22/2020  USA-53061  Snohomish  Washington      0       0.14
# 2  1/23/2020  USA-53061  Snohomish  Washington      0       0.14
# 3  1/24/2020  USA-53061  Snohomish  Washington      0       0.14
# 4  1/24/2020  USA-17031       Cook    Illinois      1       0.14
#
#    cases_avg_per_100k  deaths  deaths_avg  deaths_avg_per_100k
# 0                0.02       0         0.0                  0.0
# 1                0.02       0         0.0                  0.0
# 2                0.02       0         0.0                  0.0
# 3                0.02       0         0.0                  0.0
# 4                0.00       0         0.0                  0.0

# %%
print(data.columns.tolist())
# Out:
# ['date', 'geoid', 'county', 'state', 'cases', 'cases_avg', 'cases_avg_per_100k', 'deaths', 'deaths_avg', 'deaths_avg_per_100k']

# %%
# dropping null value columns to avoid errors
data.dropna(inplace = True)

# %%
# new data frame with split value columns
new = data["geoid"].str.split("-", n = 1, expand = True)
  
# making separate first name column from new data frame
data["drop_USA"]= new[0]
  
# making separate last name column from new data frame
data["FIPS_Code"]= new[1]
  
# Dropping old Name columns
data.drop(columns =["drop_USA"], inplace = True)
  
# df display
data
# Out:
#               date      geoid      county                     state  cases  \
# 0        1/21/2020  USA-53061   Snohomish                Washington      1
# 1        1/22/2020  USA-53061   Snohomish                Washington      0
# 2        1/23/2020  USA-53061   Snohomish                Washington      0
# 3        1/24/2020  USA-53061   Snohomish                Washington      0
# 4        1/24/2020  USA-17031        Cook                  Illinois      1
# ...            ...        ...         ...                       ...    ...
# 888550  12/31/2020  USA-69120      Tinian  Northern Mariana Islands      0
# 888551  12/31/2020  USA-69110      Saipan  Northern Mariana Islands      0
# 888553  12/31/2020  USA-78030  St. Thomas            Virgin Islands      8
# 888554  12/31/2020  USA-78020    St. John            Virgin Islands      6
# 888555  12/31/2020  USA-78010   St. Croix            Virgin Islands      7
#
#         cases_avg  cases_avg_per_100k  deaths  deaths_avg  \
# 0            0.14                0.02       0         0.0
# 1            0.14                0.02       0         0.0
# 2            0.14                0.02       0         0.0
# 3            0.14                0.02       0         0.0
# 4            0.14                0.00       0         0.0
# ...           ...                 ...     ...         ...
# 888550       0.00                0.00       0         0.0
# 888551       0.57                1.19       0         0.0
# 888553       3.71                7.19       0         0.0
# 888554       1.14               27.41       0         0.0
# 888555       4.29                8.47       0         0.0
#
#         deaths_avg_per_100k FIPS_Code
# 0                       0.0     53061
# 1                       0.0     53061
# 2                       0.0     53061
# 3                       0.0     53061
# 4                       0.0     17031
# ...                     ...       ...
# 888550                  0.0     69120
# 888551                  0.0     69110
# 888553                  0.0     78030
# 888554                  0.0     78020
# 888555                  0.0     78010
#
# [877322 rows x 11 columns]

# %%
#Transfor COVID dataframe
data_columns = ["county", "state", "cases_avg_per_100k", "deaths_avg_per_100k","FIPS_Code"]
covid_transformed = data[data_columns].copy()
covid_transformed.head()
# Out:
#       county       state  cases_avg_per_100k  deaths_avg_per_100k FIPS_Code
# 0  Snohomish  Washington                0.02                  0.0     53061
# 1  Snohomish  Washington                0.02                  0.0     53061
# 2  Snohomish  Washington                0.02                  0.0     53061
# 3  Snohomish  Washington                0.02                  0.0     53061
# 4       Cook    Illinois                0.00                  0.0     17031

# %%
#Rename columns
covid_transformed.rename(columns={"cases_avg_per_100k": "Cases/100K Ave", "deaths_avg_per_100k": "Deaths/100K Ave"})
# Out:
#             county                     state  Cases/100K Ave  Deaths/100K Ave  \
# 0        Snohomish                Washington            0.02              0.0
# 1        Snohomish                Washington            0.02              0.0
# 2        Snohomish                Washington            0.02              0.0
# 3        Snohomish                Washington            0.02              0.0
# 4             Cook                  Illinois            0.00              0.0
# ...            ...                       ...             ...              ...
# 888550      Tinian  Northern Mariana Islands            0.00              0.0
# 888551      Saipan  Northern Mariana Islands            1.19              0.0
# 888553  St. Thomas            Virgin Islands            7.19              0.0
# 888554    St. John            Virgin Islands           27.41              0.0
# 888555   St. Croix            Virgin Islands            8.47              0.0
#
#        FIPS_Code
# 0          53061
# 1          53061
# 2          53061
# 3          53061
# 4          17031
# ...          ...
# 888550     69120
# 888551     69110
# 888553     78030
# 888554     78020
# 888555     78010
#
# [877322 rows x 5 columns]

# %%
covid_transformed.to_csv('Resources/covid_cleaned.csv', index=True)
